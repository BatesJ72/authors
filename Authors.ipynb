# %%
import pandas as pd
import numpy as np

# %%
# read in data
df = pd.read_csv("data.csv", encoding= 'unicode_escape')

# %%
df.head()
# Out:
#                 Author Min. estimated sales Max. estimated sales  \
# 0  William Shakespeare         2 billion[1]         4 billion[2]
# 1      Agatha Christie         2 billion[3]         4 billion[2]
# 2     Barbara Cartland       500 million[4]         1 billion[5]
# 3       Danielle Steel       500 million[6]       800 million[7]
# 4       Harold Robbins       750 million[8]       750 million[9]
#
#   Original language                               Genre or major works  \
# 0           English                                   Plays and poetry
# 1           English  Whodunits including the Miss Marple and Hercul...
# 2           English                                            Romance
# 3           English                                            Romance
# 4           English                                          Adventure
#
#   Number of books Nationality
# 0              42     English
# 1              85     English
# 2             723     English
# ...

# %%
df.tail()
# Out:
#                 Author Min. estimated sales Max. estimated sales  \
# 63        John Creasey                  NaN     100 million[163]
# 64   James A. Michener                  NaN     100 million[164]
# 65  Mary Higgins Clark     100 million[166]     100 million[167]
# 66        Penny Jordan      90 million[168]     100 million[169]
# 67   Patricia Cornwell                  NaN     100 million[170]
#
#    Original language Genre or major works Number of books Nationality
# 63           English       Crime thriller             600     British
# 64           English           Historical              47    American
# 65           English             Thriller             NaN    American
# 66           English              Romance            200+     British
# 67           English             Thriller             34+    American

# %%
# rename header
def clean_header(header_string):
    return header_string.lower().replace(" ", "_").replace(".","")

df = df.rename(columns = clean_header)

df.head()
# Out:
#                 author min_estimated_sales max_estimated_sales  \
# 0  William Shakespeare        2 billion[1]        4 billion[2]
# 1      Agatha Christie        2 billion[3]        4 billion[2]
# 2     Barbara Cartland      500 million[4]        1 billion[5]
# 3       Danielle Steel      500 million[6]      800 million[7]
# 4       Harold Robbins      750 million[8]      750 million[9]
#
#   original_language                               genre_or_major_works  \
# 0           English                                   Plays and poetry
# 1           English  Whodunits including the Miss Marple and Hercul...
# 2           English                                            Romance
# 3           English                                            Romance
# 4           English                                          Adventure
#
#   number_of_books nationality
# 0              42     English
# 1              85     English
# 2             723     English
# 3             179    American
# ...

# %%
# get rid of brackets

df["min_estimated_sales"] = df["min_estimated_sales"].str[:-3]
df["max_estimated_sales"] = df["max_estimated_sales"].str[:-3]

df.head()
# Out:
#                 author min_estimated_sales max_estimated_sales  \
# 0  William Shakespeare           2 billion           4 billion
# 1      Agatha Christie           2 billion           4 billion
# 2     Barbara Cartland         500 million           1 billion
# 3       Danielle Steel         500 million         800 million
# 4       Harold Robbins         750 million         750 million
#
#   original_language                               genre_or_major_works  \
# 0           English                                   Plays and poetry
# 1           English  Whodunits including the Miss Marple and Hercul...
# 2           English                                            Romance
# 3           English                                            Romance
# 4           English                                          Adventure
#
#   number_of_books nationality
# 0              42     English
# 1              85     English
# 2             723     English
# 3             179    American
# ...

# %%
# standardize genres

df["genre_or_major_works"].unique()

df.groupby(df["genre_or_major_works"]).count()

df["genere_original"] = df["genre_or_major_works"]

df=df.fillna("blank")

df.genre_or_major_works = df.genre_or_major_works.apply(lambda x: 'fantasy,\xa0fiction' if 'Harry Potter,\xa0Fantastic Beasts and Where to Find Them,\xa0Cormoran Strike,\xa0fantasy,\xa0crime fiction' in x else x)
df.genre_or_major_works = df.genre_or_major_works.apply(lambda x: 'whodunits,\xa0detective,\xa0crime fiction,\xa0fiction' if 'Whodunits\xa0including the\xa0Miss Marple\xa0and\xa0Hercule Poirot\xa0series' in x else x)
df.genre_or_major_works = df.genre_or_major_works.apply(lambda x: 'whodunits,\xa0detective,\xa0crime fiction,\xa0fiction' if 'Detective' in x else x)
df.genre_or_major_works = df.genre_or_major_works.apply(lambda x: 'romance,\xa0adventure,\xa0fiction' if 'Dime novels' in x else x)
df.genre_or_major_works = df.genre_or_major_works.apply(lambda x: "absurdist literature,\xa0children's literature,\xa0fiction" if "Alice's Adventures in Wonderland, absurdist literature" in x else x)
df.genre_or_major_works = df.genre_or_major_works.apply(lambda x: "children's literature,\xa0fiction,\xa0illustrated children's books" if "Illustrated children's books" in x else x)
df.genre_or_major_works = df.genre_or_major_works.apply(lambda x: 'detective,\xa0crime fiction,\xa0espionage' if 'Espionage,\xa0Jason Bourne' in x else x)
df.genre_or_major_works = df.genre_or_major_works.apply(lambda x: 'romance,\xa0fiction' if 'Fifty Shades of Grey' in x else x)
df.genre_or_major_works = df.genre_or_major_works.apply(lambda x: 'fiction' if 'The Baby-sitters Club' in x else x)
df.genre_or_major_works = df.genre_or_major_works.apply(lambda x: "children's literature,\xa0fiction,\xa0illustrated children's books" if 'Clifford the Big Red Dog' in x else x)
df.genre_or_major_works = df.genre_or_major_works.apply(lambda x: 'romance,\xa0fiction,\xa0gothic fiction,\xa0vampires' if 'Gothic fiction,\xa0vampires,\xa0Interview with the Vampire\xa0(The Vampire Chronicles)' in x else x)
df.genre_or_major_works = df.genre_or_major_works.apply(lambda x: 'romance,\xa0fiction,\xa0vampires' if 'The Twilight Saga,\xa0The Host, romance' in x else x)
df.genre_or_major_works = df.genre_or_major_works.apply(lambda x: "children's literature,\xa0fiction,\xa0illustrated children's books" if "Children's literature,\xa0Mr. Men" in x else x)
df.genre_or_major_works = df.genre_or_major_works.apply(lambda x: 'detective,\xa0crime fiction,\xa0espionage' if 'James Bond' in x else x)
df.genre_or_major_works = df.genre_or_major_works.apply(lambda x: 'thriller,\xa0adventure,\xa0fiction' if 'Medical thriller\xa0Coma' in x else x)
df.genre_or_major_works = df.genre_or_major_works.apply(lambda x: "children's literature,\xa0fiction,\xa0theology,\xa0fantasy" if 'The Chronicles of Narnia, fantasy, popular theology' in x else x)
df.genre_or_major_works = df.genre_or_major_works.apply(lambda x: "children's literature,\xa0fiction,\xa0science fiction,\xa0fantasy" if 'Tarzan,\xa0Barsoom\xa0and\xa0Pellucidar\xa0series,\xa0science fantasy' in x else x)
df.genre_or_major_works = df.genre_or_major_works.apply(lambda x: 'whodunits,\xa0detective,\xa0crime fiction,\xa0fiction' if 'Nero Wolfe' in x else x)
df.genre_or_major_works = df.genre_or_major_works.apply(lambda x: "children's literature,\xa0fiction,\xa0illustrated children's books" if 'Peter Rabbit' in x else x)
df.genre_or_major_works = df.genre_or_major_works.apply(lambda x: "adventure,\xa0fiction,\xa0fantasy" if 'The Lord of the Rings,\xa0The Hobbit, classical fantasy' in x else x)
df.genre_or_major_works = df.genre_or_major_works.apply(lambda x: 'thriller,\xa0adventure,\xa0fiction' if 'Thriller,\xa0Robert Langdon' in x else x)
# df.genre_or_major_works = df.genre_or_major_works.apply(lambda x: 'literary fiction' if 'literary' in x else x)
# df.genre_or_major_works = df.genre_or_major_works.apply(lambda x: 'literary fiction' if 'Literature' in x else x)
# df.genre_or_major_works = df.genre_or_major_works.apply(lambda x: 'literary fiction' if 'Vampire' in x else x)
# df.genre_or_major_works = df.genre_or_major_works.apply(lambda x: 'literary fiction' if 'Detective' in x else x)
# df.genre_or_major_works = df.genre_or_major_works.apply(lambda x: 'literary fiction' if 'thriller' in x else x)
# df.genre_or_major_works = df.genre_or_major_works.apply(lambda x: 'literary fiction' if 'adventure' in x else x)
# df.genre_or_major_works = df.genre_or_major_works.apply(lambda x: 'literary fiction' if 'literature' in x else x)
# df.genre_or_major_works = df.genre_or_major_works.apply(lambda x: 'literary fiction' if 'literary' in x else x)
# df.genre_or_major_works = df.genre_or_major_works.apply(lambda x: 'literary fiction' if 'Literature' in x else x)

df.head()
# Out:
#                 author min_estimated_sales max_estimated_sales  \
# 0  William Shakespeare           2 billion           4 billion
# 1      Agatha Christie           2 billion           4 billion
# 2     Barbara Cartland         500 million           1 billion
# 3       Danielle Steel         500 million         800 million
# 4       Harold Robbins         750 million         750 million
#
#   original_language                          genre_or_major_works  \
# 0           English                              Plays and poetry
# 1           English  whodunits, detective, crime fiction, fiction
# 2           English                                       Romance
# 3           English                                       Romance
# 4           English                                     Adventure
#
#   number_of_books nationality  \
# 0              42     English
# 1              85     English
# 2             723     English
# 3             179    American
# ...

# %%
df["genre_or_major_works"].unique()
# Out:
# array(['Plays\xa0and\xa0poetry',
#        'whodunits,\xa0detective,\xa0crime fiction,\xa0fiction', 'Romance',
#        'Adventure',
#        "Children's literature,\xa0Noddy,\xa0The Famous Five,\xa0The Secret Seven",
#        'Suspense', 'fantasy,\xa0fiction', 'Adolescent adventures',
#        "Children's literature", 'romance,\xa0adventure,\xa0fiction',
#        'Goosebumps\xa0series,\xa0Fear Street\xa0series, horror, comedy',
#        'Horror,\xa0thriller,\xa0science fiction,\xa0fantasy',
#        "Horror,\xa0science fiction,\xa0fantasy,\xa0It,\xa0The Shining,\xa0The Stand,\xa0Pet Sematary,\xa0Salem's Lot,\xa0The Green Mile",
#        'Saga,\xa0thriller,\xa0short stories,\xa0Kane and Abel,\xa0The Clifton Chronicles',
#        'Western', 'Mystery,\xa0Perry Mason',
#        'detective,\xa0crime fiction,\xa0espionage',
#        'Thriller,\xa0Alex Cross', 'Berenstain Bears', 'Legal thriller',
#        'adventure,\xa0fiction,\xa0fantasy',
# ...

# %%
df.groupby(df["genre_or_major_works"]).count()
# Out:
#                                                     author  \
# genre_or_major_works
# Adolescent adventures                                    1
# Adventure                                                1
# Adventure, thriller, war stories                         1
# Adventure, Dirk Pitt                                     1
# African adventure                                        1
# Berenstain Bears                                         1
# Children's literature                                    2
# Children's literature, Noddy, The Famous Five, ...       1
# Crime thriller                                           1
# Goosebumps series, Fear Street series, horror, ...       1
# Historical                                               1
# Horror, science fiction, fantasy, It, The Shini...       1
# Horror, thriller, science fiction, fantasy               1
# Legal thriller                                           1
# ...

# %%
df.head()
# Out:
#                 author min_estimated_sales max_estimated_sales  \
# 0  William Shakespeare           2 billion           4 billion
# 1      Agatha Christie           2 billion           4 billion
# 2     Barbara Cartland         500 million           1 billion
# 3       Danielle Steel         500 million         800 million
# 4       Harold Robbins         750 million         750 million
#
#   original_language                          genre_or_major_works  \
# 0           English                              Plays and poetry
# 1           English  whodunits, detective, crime fiction, fiction
# 2           English                                       Romance
# 3           English                                       Romance
# 4           English                                     Adventure
#
#   number_of_books nationality  \
# 0              42     English
# 1              85     English
# 2             723     English
# 3             179    American
# ...

# %%
df.to_Csv
